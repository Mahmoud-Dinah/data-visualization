# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Set seaborn default theme

# %%
sns.set()

# %%
sns.set_theme()

# %%
sns.set_style("dark")

# %% [markdown]
# ## Import .CSV File data

# %%
df = pd.read_csv("data.csv")

df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %% [markdown]
# ## Use lmplot function to make a scatter plot

# %%
sns.lmplot(x='Height',y='Weight', data=df)

# %% [markdown]
# ## Create a diffrent style visualization

# %%
sns.lmplot(x='Height', y='Weight', data=df,hue='Weight')

# %%
sns.catplot(data=df, kind="bar", x="Weight", y="Height")

# %%
sns.catplot(data=df, kind="violin", x="Weight", y="Height")

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# insight:
#
# - using seaborn is better thn using matplotlib
